# %%
#bai5
a = int(input())
b = int(input())
print("Kết quả của a mũ b là:", a ** b)

# %%
#bai6
ch = input("Nhập một ký tự từ 'a' đến 'z': ")
unicode_code = ord(ch)
upper_ch = chr(unicode_code - 32)   
print("Mã Unicode của ký tự vừa nhập là:", unicode_code)
print("Ký tự hoa tương ứng là:", upper_ch)

# %%
#bai7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print("Kết quả của A:", A)
print("Kết quả của B:", B)

# %%
#bai8
C = float(input("Nhập vào độ C: "))
F = (9/5) * C + 32
F_hihi = round(F, 2)
print("Độ F là:", F_hihi)

# %%
#bai10
names = input("Nhập tên 3 người (cách nhau bởi dấu cách): ").split()
names_reversed = names[::-1]
print(f"Hi {names_reversed[0]}, {names_reversed[1]} and {names_reversed[2]}.")

# %%
#bai11
h = int(input())
m = int(input())
seconds = h * 3600 + m * 60
print(seconds)

# %%
#bai12
n = int(input())
stickers = 6 * n * n
print(stickers)

# %%
#bai13
a = int(input())
b = int(input())

result = (a * b) % 10
print(result)

# %%
#bai14
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
a, b = b, a
print("Giá trị sau khi hoán đổi: a =", a, ", b =", b)

# %%
#bai15
n = int(input())

star_number = 3 * n * (n - 1) + 1
print(star_number)

# %%
#bai16
print("Spring")
print("Summer")
print("Autumn")
print("Winter")

# %%
#bai17
print("  *  ")
print(" *** ")
print("*****")

# %%
#bai18
print("### # #     ### ###  ")
print(" #    #    #    #    #  ")
print(" #    #     #   #    #  ")
print(" #    #    #    #    #  ")
print(" #    # #       #    #")
# Out:
# ### # #     ### ###
#  #    #    #    #    #
#  #    #     #   #    #
#  #    #    #    #    #
#  #    # #       #    #

# %%
#bai19
print("Monday")
print("tuesday")
print("wednesday")
print("thursday")
print("firday")
print("saturday")
print("sunday")
# Out:
# Monday
# tuesday
# wednesday
# thursday
# firday
# saturday
# sunday

# %%
#bai20
print("jauary")
print("feruary")
# Out:
# jauary
# feruary

# %%
#bai21
for i in range(10):
    print("Hello, world")
